# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart.csv')

# %%
new_names =['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df= pd.read_csv('heart.csv',skiprows=1,names=new_names)
df.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0   44    1   4      130  209   0        1     127     0       0     ?  ?
# 1   60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2   55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3   66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4   66    1   3      120    0   0        1     120     0    -0.5     1  ?
#
#   thal  num
# 0    ?    0
# 1    ?    2
# 2    ?    1
# 3    ?    0
# 4    ?    0

# %%
df= pd.read_csv('heart.csv',skiprows=1,names=new_names)
df.head(10)
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0   44    1   4      130  209   0        1     127     0       0     ?  ?
# 1   60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2   55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3   66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4   66    1   3      120    0   0        1     120     0    -0.5     1  ?
# 5   65    1   4      150  236   1        1     105     1       0     ?  ?
# 6   60    1   3      180    0   0        1     140     1     1.5     2  ?
# 7   60    1   3      120    0   ?        0     141     1       2     1  ?
# 8   60    1   2      160  267   1        1     157     0     0.5     2  ?
# 9   56    1   2      126  166   0        1     140     0       0     ?  ?
#
#   thal  num
# 0    ?    0
# 1    ?    2
# 2    ?    1
# 3    ?    0
# 4    ?    0
# 5    ?    3
# 6    ?    0
# 7    ?    3
# 8    ?    1
# 9    ?    0

# %%
df= pd.read_csv('heart.csv',skiprows=1,names=new_names)
df.tail(7)
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 153   56    1   4      128  223   0        1     119     1       2     3  ?
# 154   69    1   4        ?    ?   1        0       ?     ?       ?     ?  ?
# 155   64    1   4      150  193   0        1     135     1     0.5     2  ?
# 156   72    1   4      160    ?   1        2     130     0     1.5     ?  ?
# 157   69    1   4        ?  210   1        1       ?     ?       ?     ?  ?
# 158   56    1   4        ?  282   1        0       ?     ?       ?     ?  ?
# 159   62    1   4        ?  170   0        1     120     1       3     ?  ?
#
#     thal  num
# 153    ?    2
# 154    ?    2
# 155    ?    2
# 156    ?    2
# 157    ?    2
# 158    ?    1
# 159    ?    4

# %%
df.shape
# Out:
# (160, 14)

# %%
df= pd.read_csv('heart.csv',skiprows=1,names=new_names)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       160 non-null    int64
#  1   sex       160 non-null    int64
#  2   cp        160 non-null    int64
#  3   trestbps  160 non-null    object
#  4   chol      160 non-null    object
#  5   fbs       160 non-null    object
#  6   restecg   160 non-null    int64
#  7   thalach   160 non-null    object
#  8   exang     160 non-null    object
#  9   oldpeak   160 non-null    object
#  10  slope     160 non-null    object
#  11  ca        160 non-null    object
#  12  thal      160 non-null    object
#  13  num       160 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 17.6+ KB

# %%
df= pd.read_csv('heart.csv',skiprows=1,names=new_names)
df.describe()
# Out:
#              age         sex         cp     restecg         num
# count  160.00000  160.000000  160.00000  160.000000  160.000000
# mean    59.33750    0.975000    3.48750    0.643750    1.525000
# std      7.92408    0.156615    0.80866    0.627933    1.223203
# min     35.00000    0.000000    1.00000    0.000000    0.000000
# 25%     55.00000    1.000000    3.00000    0.000000    0.000000
# 50%     60.00000    1.000000    4.00000    1.000000    1.000000
# 75%     64.00000    1.000000    4.00000    1.000000    3.000000
# max     77.00000    1.000000    4.00000    2.000000    4.000000

# %%
df= pd.read_csv('heart.csv',skiprows=1,names=new_names)
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df.corr()
# Out:
#               age       sex        cp   restecg       num
# age      1.000000 -0.023565 -0.023875  0.048331  0.317069
# sex     -0.023565  1.000000  0.096836  0.164677  0.134603
# cp      -0.023875  0.096836  1.000000  0.009754  0.114767
# restecg  0.048331  0.164677  0.009754  1.000000 -0.008802
# num      0.317069  0.134603  0.114767 -0.008802  1.000000

# %%
df.hist(figsize=(14,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BFF2567F0>,
# ...
#       dtype=object)

# %%
sns.barplot(df['sex'],df['age'])
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=10,test_size=0.3,shuffle=True)

# %%
x_test.shape
# Out:
# (48, 13)

# %%
x_train.shape
# Out:
# (112, 13)

# %%
y_train
# Out:
# array([1, 2, 1, 3, 3, 3, 1, 1, 0, 1, 2, 1, 3, 4, 2, 1, 2, 0, 3, 3, 0, 3,
#        1, 3, 1, 1, 0, 1, 3, 3, 0, 0, 0, 4, 1, 0, 1, 3, 0, 3, 2, 2, 3, 0,
#        0, 2, 1, 0, 0, 3, 2, 3, 1, 2, 0, 3, 2, 3, 0, 0, 1, 3, 0, 2, 4, 2,
#        4, 0, 1, 3, 1, 3, 2, 0, 3, 0, 0, 1, 0, 0, 3, 3, 3, 3, 0, 1, 2, 1,
#        2, 0, 1, 2, 4, 0, 0, 1, 2, 0, 3, 1, 2, 1, 0, 3, 1, 2, 1, 1, 2, 4,
#        1, 0], dtype=int64)

# %%
y_train.size
# Out:
# 112
